# %%
# ---------------------
# Runned on Python 3.6
# Assignment - 01
# August 27, 2018
# Ben Pradipta Rukmawan
# ---------------------

# %%
# -----------------------
# General package import:
# -----------------------
import pandas as pd      # Data structures and analysis tools

# %%
# ------------------------------------
# Read and extract data from CSV file:
# ------------------------------------
wrdsdata = pd.read_csv("C:\\Users\\drysteel\\Downloads\\FERM 6V99.FS3 - Homework 01.csv")

# %%
# -----------------
# Create dataframe:
# -----------------
# Show number of columns (observations) and rows (variables) in the dataframe
wrdsdata.shape

# Show the first few rows of the dataframe
wrdsdata.head()
# Out:
#    gvkey      conm costat      cusip  exchg     sic       start  tic    CNUM  \
# 0   1004  AAR CORP      A  000361105    1.0  5080.0  19870218.0  AIR  000361
# 1   1004  AAR CORP      A  000361105    1.0  5080.0  19870218.0  AIR  000361
# 2   1004  AAR CORP      A  000361105    1.0  5080.0  19870218.0  AIR  000361
# 3   1004  AAR CORP      A  000361105    1.0  5080.0  19870218.0  AIR  000361
# 4   1004  AAR CORP      A  000361105    1.0  5080.0  19870218.0  AIR  000361
#
#    CIC   ...     txpdqf txpdqfr txtqf  txtqfr  xintqf  xintqfr  xrdqf  xrdqfr  \
# 0  105   ...        NaN     NaN   NaN     NaN     NaN      NaN    NaN     NaN
# 1  105   ...        NaN     NaN   NaN     NaN     NaN      NaN    NaN     NaN
# 2  105   ...        NaN     NaN   NaN     NaN     NaN      NaN    NaN     NaN
# 3  105   ...        NaN     NaN   NaN     NaN     NaN      NaN    NaN     NaN
# 4  105   ...        NaN     NaN   NaN     NaN     NaN      NaN    NaN     NaN
#
#    xsgaqf  xsgaqfr
# ...

# %%
# -----------------------
# Check for null values:
# -----------------------
# Show total number of null values in each column of the dataframe 
wrdsdata.isnull().sum()
# Out:
# gvkey              0
# conm              38
# costat            38
# cusip             38
# exchg            118
# sic               83
# start           2392
# tic               49
# CNUM              38
# CIC               38
# datadate           0
# compstq       526603
# compstqr      596422
# finalqprd      47436
# fqtr             121
# fyrq             121
# qtrend           121
# qtryr            121
# rdq            50095
# scfq           74865
# srcq             217
# staltq        602145
# staltqr       604696
# updq             185
# acchgq         58769
# acchgq_dc     575604
# acchgqr        74927
# acchgqr_dc    572985
# acoq           99914
# acoq_dc       604969
#                ...
# dlttqf        545726
# dlttqfr       601545
# dpactqf       596671
# dpactqfr      604604
# dpqf          566859
# dpqfr         589579
# epspxqf       567095
# epspxqfr      596590
# fcaqf         604634
# fcaqfr        604934
# ibadjqf       585507
# ibadjqfr      604024
# ...

# %%
# -----------------------------------------------
# Extract statistical variables from the dataset:
# -----------------------------------------------
# Show statistical variables for all
wrdsdata.describe()
# Out:
#                gvkey          exchg            sic         start  \
# count  604969.000000  604851.000000  604886.000000  6.025770e+05
# mean    75463.414301       4.552567    4859.936978  1.998192e+07
# std     68725.145358       3.570942    2096.111090  8.613354e+04
# min      1004.000000       1.000000     100.000000  1.987022e+07
# 25%     15136.000000       1.000000    3312.000000  1.990081e+07
# 50%     61198.000000       3.000000    4911.000000  1.998071e+07
# 75%    141363.000000      10.000000    6331.000000  2.004063e+07
# max    326688.000000      10.000000    9998.000000  2.018050e+07
#
#            datadate     finalqprd           fqtr           fyrq  \
# count  6.049690e+05  5.575330e+05  604848.000000  604848.000000
# mean   2.007907e+07  2.008372e+07       2.475313      10.380712
# std    5.200018e+04  5.220454e+04       1.115553       3.104906
# min    2.000013e+07  2.000021e+07       1.000000       1.000000
# ...

# %%
# -----------------------------------------------
# Extract statistical variables from the dataset:
# -----------------------------------------------
# Show statistical categories for all
wrdsdata.describe(include = ['O'])
# Out:
#                      conm  costat      cusip     tic    CNUM     CIC compstq  \
# count              604931  604931     604931  604920  604931  604931   78366
# unique              18361       2      18364   18361   18271     220      16
# top     ENOVA SYSTEMS INC       A  29355M200     SBS  092113     10X      AZ
# freq                  102  370203        102      79     144  168409   33881
#
#        compstqr staltq staltqr   ...   txpdqf txpdqfr txtqf txtqfr  xintqf  \
# count      8547   2824     273   ...    31469     946  3914    339  111844
# unique       14      1       1   ...        1       1     4      2       7
# top          AZ     TL      TL   ...       BH      BH    BH     BH      QA
# freq       4161   2824     273   ...    31469     946  2710    254  105081
#
#        xintqfr  xrdqf xrdqfr xsgaqf xsgaqfr
# count    16640  37732   1880   8154     771
# unique       6      4      4      1       1
# top         QA     BF     BF     AC      AC
# ...

# %%
# -------------------------------------------------
# Remove columns with more than 50% missing values:
# -------------------------------------------------
wrdsdata_cols= wrdsdata[wrdsdata.columns[wrdsdata.isnull().sum() / wrdsdata.shape [0] > 0.5]]

# Show first few rows of the dataset
wrdsdata_cols.head()
# Out:
#   compstq compstqr staltq staltqr  acchgq_dc  acchgqr_dc  acoq_dc  acoqr_dc  \
# 0     NaN      NaN    NaN     NaN        NaN         NaN      NaN       NaN
# 1     NaN      NaN    NaN     NaN        NaN         NaN      NaN       NaN
# 2      AC      NaN    NaN     NaN        NaN         NaN      NaN       NaN
# 3      AC      NaN    NaN     NaN        NaN         NaN      NaN       NaN
# 4     NaN      NaN    NaN     NaN        NaN         NaN      NaN       NaN
#
#    actq_dc  actqr_dc   ...     txpdqf  txpdqfr  txtqf  txtqfr  xintqf  \
# 0      NaN       NaN   ...        NaN      NaN    NaN     NaN     NaN
# 1      NaN       NaN   ...        NaN      NaN    NaN     NaN     NaN
# 2      NaN       NaN   ...        NaN      NaN    NaN     NaN     NaN
# 3      NaN       NaN   ...        NaN      NaN    NaN     NaN     NaN
# 4      NaN       NaN   ...        NaN      NaN    NaN     NaN     NaN
#
#    xintqfr  xrdqf  xrdqfr  xsgaqf  xsgaqfr
# 0      NaN    NaN     NaN     NaN      NaN
# ...

# %%
# ----------------------------------------------
# Show all statistical variables and categories:
# ----------------------------------------------
# Combines variables and categories for all
wrdsdata.describe(include = 'all').style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_916ab7cf_aa3c_11e8_b119_bc6a073e6898" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >gvkey</th>
#         <th class="col_heading level0 col1" >conm</th>
#         <th class="col_heading level0 col2" >costat</th>
#         <th class="col_heading level0 col3" >cusip</th>
#         <th class="col_heading level0 col4" >exchg</th>
#         <th class="col_heading level0 col5" >sic</th>
#         <th class="col_heading level0 col6" >start</th>
#         <th class="col_heading level0 col7" >tic</th>
#         <th class="col_heading level0 col8" >CNUM</th>
#         <th class="col_heading level0 col9" >CIC</th>
#         <th class="col_heading level0 col10" >datadate</th>
#         <th class="col_heading level0 col11" >compstq</th>
#         <th class="col_heading level0 col12" >compstqr</th>
#         <th class="col_heading level0 col13" >finalqprd</th>
# ...
